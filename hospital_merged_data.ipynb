# %%
#https://healthdata.gov/resource/anag-cw7u.json

# %%
import pandas as pd
import folium

# %%
import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("healthdata.gov", None)


results = client.get("anag-cw7u",limit = None)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df.head()
# Out:
#   hospital_pk          collection_week state     ccn  \
# 0      441305  2021-09-03T00:00:00.000    TN  441305
# 1      191306  2021-09-03T00:00:00.000    LA  191306
# 2      452086  2021-09-03T00:00:00.000    TX  452086
# 3      150113  2021-09-03T00:00:00.000    IN  150113
# 4      501322  2021-09-03T00:00:00.000    WA  501322
#
#                                        hospital_name  \
# 0                           MACON COMMUNITY HOSPITAL
# 1                     WEST FELICIANA PARISH HOSPITAL
# 2    POST ACUTE MEDICAL SPECIALTY HOSPITAL CORPUS CH
# 3  COMMUNITY HOSPITAL OF ANDERSON AND MADISON COUNTY
# 4                     FERRY COUNTY MEMORIAL HOSPITAL
#
#                             address                city    zip  \
# 0                 204 MEDICAL DRIVE           LAFAYETTE  37083
# 1  5266 COMMERCE STREET, BUILDING B  SAINT FRANCISVILLE  70775
# 2           345 S WATER ST3RD FLOOR      CORPUS CHRISTI  78401
# 3                1515 N MADISON AVE            ANDERSON  46011
# ...

# %%
#on average beds available
hospital_data = results_df[['state','hospital_name','address','city','zip','total_beds_7_day_avg','inpatient_beds_used_7_day_avg','total_icu_beds_7_day_avg','icu_beds_used_7_day_avg',]]

# %%
hospital_data
# Out:
#     state                                      hospital_name  \
# 0      TN                           MACON COMMUNITY HOSPITAL
# 1      LA                     WEST FELICIANA PARISH HOSPITAL
# 2      TX    POST ACUTE MEDICAL SPECIALTY HOSPITAL CORPUS CH
# 3      IN  COMMUNITY HOSPITAL OF ANDERSON AND MADISON COUNTY
# 4      WA                     FERRY COUNTY MEMORIAL HOSPITAL
# ..    ...                                                ...
# 995    MN                                     MERCY HOSPITAL
# 996    SD                             PRAIRIE LAKES HOSPITAL
# 997    TX       BAYLOR SCOTT AND WHITE MEDICAL CENTER UPTOWN
# 998    MO                           ST MARY'S MEDICAL CENTER
# 999    CA                           SUTTER LAKESIDE HOSPITAL
#
#                                      address                city    zip  \
# 0                          204 MEDICAL DRIVE           LAFAYETTE  37083
# 1           5266 COMMERCE STREET, BUILDING B  SAINT FRANCISVILLE  70775
# ...

# %%
hospital_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   state                          2000 non-null   object
#  1   hospital_name                  2000 non-null   object
#  2   address                        1999 non-null   object
#  3   city                           1999 non-null   object
#  4   zip                            2000 non-null   object
#  5   total_beds_7_day_avg           2000 non-null   object
#  6   inpatient_beds_used_7_day_avg  2000 non-null   object
#  7   total_icu_beds_7_day_avg       2000 non-null   object
#  8   icu_beds_used_7_day_avg        2000 non-null   object
# dtypes: object(9)
# memory usage: 140.8+ KB

# %%
final_data = hospital_data.dropna()

# %%
loc = pd.read_excel('zips_lat_long.xlsx',dtype={'zip': 'str'})

# %%
df_zip = pd.io.excel.read_excel('zips_lat_long.xlsx', dtype={'zip': 'str'})

# %%
loc = df_zip.rename(columns = {'ZIP':'zip'})

# %%
merged_df = hosp.merge(loc,how='left', on = 'zip')

# %%
merged_df
# Out:
#       Unnamed: 0 state                           hospital_name  \
# 0              0    MA                     ST VINCENT HOSPITAL
# 1              1    PA                   CURAHEALTH PITTSBURGH
# 2              2    SD         MONUMENT HEALTH CUSTER HOSPITAL
# 3              3    FL        ASCENSION ST VINCENT'S SOUTHSIDE
# 4              4    KY                        LOURDES HOSPITAL
# ...          ...   ...                                     ...
# 1995        1995    CA            MEMORIAL HOSPITAL OF GARDENA
# 1996        1996    MI                      MCLAREN PORT HURON
# 1997        1997    CA                 TRI-CITY MEDICAL CENTER
# 1998        1998    TX  KINDRED HOSPITAL FORT WORTH- MANSFIELD
# 1999        1999    WI                   AURORA MEDICAL CENTER
#
#                         address          city    zip  total_beds_7_day_avg  \
# 0             123 SUMMER STREET     WORCESTER   1608                 243.0
# ...

# %%
merged_df.to_csv('hospital_zip.csv')

# %%
df = pd.read_csv('hospital_zip.csv')

# %%
df =df.dropna()

# %%
del df['Unnamed: 0']

# %%
del df['Unnamed: 0.1']

# %%
map = folium.Map(location=[df.LAT.mean(), df.LNG.mean()], zoom_start=3, control_scale=True)

# %%
for index, location_info in locations.iterrows():
    folium.Marker([location_info["LAT"], location_info["LNG"]]).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
