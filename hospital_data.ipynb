# %%
#https://healthdata.gov/resource/anag-cw7u.json

# %%
import pandas as pd
import json

# %%
import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("healthdata.gov", None)


results = client.get("anag-cw7u", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df
# Out:
#      hospital_pk          collection_week state     ccn  \
# 0         391307  2021-08-27T00:00:00.000    PA  391307
# 1         220171  2021-08-27T00:00:00.000    MA  220171
# 2         040002  2021-08-27T00:00:00.000    AR  040002
# 3         260047  2021-08-27T00:00:00.000    MO  260047
# 4         450033  2021-08-27T00:00:00.000    TX  450033
# ...          ...                      ...   ...     ...
# 1995      060116  2021-08-27T00:00:00.000    CO  060116
# 1996      440030  2021-08-27T00:00:00.000    TN  440030
# 1997      521321  2021-08-27T00:00:00.000    WI  521321
# 1998      260160  2021-08-27T00:00:00.000    MO  260160
# 1999      390119  2021-08-27T00:00:00.000    PA  390119
#
#                                     hospital_name                  address  \
# 0                           PENN HIGHLANDS TYRONE       187 HOSPITAL DRIVE
# 1     LAHEY HOSPITAL & MEDICAL CENTER, BURLINGTON        41 & 45 MALL ROAD
# ...

# %%
results_df.columns.to_list()
# Out:
# ['hospital_pk',
#  'collection_week',
#  'state',
#  'ccn',
#  'hospital_name',
#  'address',
#  'city',
#  'zip',
#  'hospital_subtype',
#  'fips_code',
#  'is_metro_micro',
#  'total_beds_7_day_avg',
#  'all_adult_hospital_beds_7_day_avg',
#  'all_adult_hospital_inpatient_beds_7_day_avg',
#  'inpatient_beds_used_7_day_avg',
#  'all_adult_hospital_inpatient_bed_occupied_7_day_avg',
#  'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg',
#  'total_adult_patients_hospitalized_confirmed_covid_7_day_avg',
#  'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_7_day_avg',
#  'total_pediatric_patients_hospitalized_confirmed_covid_7_day_avg',
#  'inpatient_beds_7_day_avg',
#  'total_icu_beds_7_day_avg',
#  'total_staffed_adult_icu_beds_7_day_avg',
#  'icu_beds_used_7_day_avg',
#  'staffed_adult_icu_bed_occupancy_7_day_avg',
#  'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_avg',
# ...

# %%
#on average beds available
# hospital_data = results_df[['state','hospital_name','hospital_name','address','city','zip','total_beds_7_day_avg','inpatient_beds_used_7_day_avg','total_icu_beds_7_day_avg','icu_beds_used_7_day_avg',]]

# %%
# hospital_data
# Out:
#      state                                hospital_name  \
# 0       PA                        PENN HIGHLANDS TYRONE
# 1       MA  LAHEY HOSPITAL & MEDICAL CENTER, BURLINGTON
# 2       AR              JOHNSON REGIONAL MEDICAL CENTER
# 3       MO                CAPITAL REGION MEDICAL CENTER
# 4       TX           VHS HARLINGEN HOSPITAL COMPANY LLC
# ...    ...                                          ...
# 1995    CO                GOOD SAMARITAN MEDICAL CENTER
# 1996    TN      MORRISTOWN HAMBLEN HOSPITAL ASSOCIATION
# 1997    WI                         RIPON MEDICAL CENTER
# 1998    MO    SOUTHEASTHEALTH CENTER OF STODDARD COUNTY
# 1999    PA                        MOSES TAYLOR HOSPITAL
#
#                                     hospital_name                  address  \
# 0                           PENN HIGHLANDS TYRONE       187 HOSPITAL DRIVE
# 1     LAHEY HOSPITAL & MEDICAL CENTER, BURLINGTON        41 & 45 MALL ROAD
# ...
